# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("Data", "diabetes.csv"))
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
target = df["Outcome"]
target_names = ["negative", "positive"]

# %%
data = df.drop("Outcome", axis=1)
feature_names = data.columns
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.6875

# %%
# Use this to visualize the tree
import graphviz 
dot_data = tree.export_graphviz(
    clf, out_file=None, 
    feature_names=feature_names,  
    class_names=target_names,  
    filled=True, rounded=True,  
    special_characters=True)  

graph = graphviz.Source(dot_data)  
graph

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7291666666666666

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.26487780227989804, 'Glucose'),
#  (0.16075944255730318, 'BMI'),
#  (0.14749575756664118, 'Age'),
#  (0.11508701740711276, 'DiabetesPedigreeFunction'),
#  (0.08684207868309908, 'BloodPressure'),
#  (0.07855195949964938, 'Pregnancies'),
#  (0.07397658401354794, 'Insulin'),
#  (0.0724093579927483, 'SkinThickness')]
